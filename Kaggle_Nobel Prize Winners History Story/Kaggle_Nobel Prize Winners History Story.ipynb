# %% [markdown]
# ## 1. The most Nobel of Prizes
# <p><img style="float: right;margin:5px 20px 5px 1px; max-width:250px" src="https://assets.datacamp.com/production/project_441/img/Nobel_Prize.png"></p>
# <p>The Nobel Prize is perhaps the world's most well known scientific award. Except for the honor, prestige and substantial prize money the recipient also gets a gold medal showing Alfred Nobel (1833 - 1896) who established the prize. Every year it's given to scientists and scholars in the categories chemistry, literature, physics, physiology or medicine, economics, and peace. The first Nobel Prize was handed out in 1901, and at that time the Prize was very Eurocentric and male-focused, but nowadays it's not biased in any way whatsoever. Surely. Right?</p>
# <p>Well, we're going to find out! The Nobel Foundation has made a dataset available of all prize winners from the start of the prize, in 1901, to 2016. Let's load it in and take a look.</p>

# %%
# Loading in required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Reading in the Nobel Prize data
nobel = pd.read_csv("D:/CSV/data Science proj 3-nobel prize/archive.csv")

# Taking a look at the first several winners
nobel
# Out:
#      Year    Category                                           Prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 964  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 965  2016       Peace                      The Nobel Peace Prize 2016
# 966  2016     Physics                 The Nobel Prize in Physics 2016
# 967  2016     Physics                 The Nobel Prize in Physics 2016
# 968  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             Motivation Prize Share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 1    "in special recognition of his poetic composit...         1/1
# 2    "for his work on serum therapy, especially its...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 964  "for his discoveries of mechanisms for autophagy"         1/1
# 965  "for his resolute efforts to bring the country...         1/1
# 966  "for theoretical discoveries of topological ph...         1/2
# 967  "for theoretical discoveries of topological ph...         1/4
# 968  "for theoretical discoveries of topological ph...         1/4
#
#      Laureate ID Laureate Type                     Full Name  Birth Date  \
# 0            160    Individual  Jacobus Henricus van 't Hoff  1852-08-30
# 1            569    Individual               Sully Prudhomme  1839-03-16
# 2            293    Individual        Emil Adolf von Behring  1854-03-15
# 3            462    Individual             Jean Henry Dunant  1828-05-08
# 4            463    Individual                Frédéric Passy  1822-05-20
# ..           ...           ...                           ...         ...
# 964          927    Individual              Yoshinori Ohsumi  1945-02-09
# 965          934    Individual            Juan Manuel Santos  1951-08-10
# 966          928    Individual             David J. Thouless  1934-09-21
# 967          929    Individual          F. Duncan M. Haldane  1951-09-14
# 968          930    Individual         J. Michael Kosterlitz  1943-06-22
#
#             Birth City     Birth Country   Sex              Organization Name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 964            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 965             Bogotá          Colombia  Male                            NaN
# 966           Bearsden    United Kingdom  Male       University of Washington
# 967             London    United Kingdom  Male           Princeton University
# 968           Aberdeen    United Kingdom  Male               Brown University
#
#     Organization City      Organization Country  Death Date Death City  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Châtenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 964             Tokyo                     Japan         NaN        NaN
# 965               NaN                       NaN         NaN        NaN
# 966       Seattle, WA  United States of America         NaN        NaN
# 967     Princeton, NJ  United States of America         NaN        NaN
# 968    Providence, RI  United States of America         NaN        NaN
#
#     Death Country
# 0         Germany
# 1          France
# 2         Germany
# 3     Switzerland
# 4          France
# ..            ...
# 964           NaN
# 965           NaN
# 966           NaN
# 967           NaN
# 968           NaN
#
# [969 rows x 18 columns]

# %%
nobel.isnull().sum()
# Out:
# Year                      0
# Category                  0
# Prize                     0
# Motivation               88
# Prize Share               0
# Laureate ID               0
# Laureate Type             0
# Full Name                 0
# Birth Date               29
# Birth City               28
# Birth Country            26
# Sex                      26
# Organization Name       247
# Organization City       253
# Organization Country    253
# Death Date              352
# Death City              370
# Death Country           364
# dtype: int64

# %%
nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 969 entries, 0 to 968
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  969 non-null    int64
#  1   Category              969 non-null    object
#  2   Prize                 969 non-null    object
#  3   Motivation            881 non-null    object
#  4   Prize Share           969 non-null    object
#  5   Laureate ID           969 non-null    int64
#  6   Laureate Type         969 non-null    object
#  7   Full Name             969 non-null    object
#  8   Birth Date            940 non-null    object
#  9   Birth City            941 non-null    object
#  10  Birth Country         943 non-null    object
#  11  Sex                   943 non-null    object
#  12  Organization Name     722 non-null    object
#  13  Organization City     716 non-null    object
#  14  Organization Country  716 non-null    object
#  15  Death Date            617 non-null    object
#  16  Death City            599 non-null    object
#  17  Death Country         605 non-null    object
# dtypes: int64(2), object(16)
# memory usage: 136.4+ KB

# %% [markdown]
# ## 2. So, who gets the Nobel Prize?
# <p>Just looking at the first couple of prize winners, or Nobel laureates as they are also called, we already see a celebrity: Wilhelm Conrad Röntgen, the guy who discovered X-rays. And actually, we see that all of the winners in 1901 were guys that came from Europe. But that was back in 1901, looking at all winners in the dataset, from 1901 to 2016, which sex and which country is the most commonly represented? </p>
# <p>(For <em>country</em>, we will use the <code>birth_country</code> of the winner, as the <code>organization_country</code> is <code>NaN</code> for all shared Nobel Prizes.)</p>

# %%
# Display the number of (possibly shared) Nobel Prizes handed
# out between 1901 and 2016
year_wise=nobel.Year.value_counts()
display(year_wise)
# print(year_wise)

# Display the number of prizes won by male and female recipients.
display(nobel.Sex.value_counts())

display(nobel.Category.value_counts())

# Display the number of prizes won by the top 10 nationalities.
nobel["Birth Country"].value_counts().head(10)
# Out:
# 2009    18
# 2013    16
# 2011    16
# 2005    16
# 2008    15
#         ..
# 1917     4
# 1914     3
# 1924     3
# 1918     2
# 1916     1
# Name: Year, Length: 113, dtype: int64
# Male      893
# Female     50
# Name: Sex, dtype: int64
# Medicine      227
# Physics       222
# Chemistry     194
# Peace         130
# Literature    113
# Economics      83
# Name: Category, dtype: int64
# United States of America    276
# United Kingdom               88
# Germany                      70
# France                       53
# Sweden                       30
# Japan                        29
# Russia                       20
# Netherlands                  19
# Canada                       18
# Italy                        18
# Name: Birth Country, dtype: int64

# %% [markdown]
# ## 3. USA dominance
# <p>Not so surprising perhaps: the most common Nobel laureate between 1901 and 2016 was a man born in the United States of America. But in 1901 all the winners were European. When did the USA start to dominate the Nobel Prize charts?</p>

# %%
# Calculating the proportion of USA born winners per decade
nobel['usa_born_winner'] = nobel["Birth Country"]=="United States of America"
nobel['decade'] = (np.floor(nobel["Year"]/10)*10).astype(int)
prop_usa_winners = nobel.groupby("decade", as_index=False)["usa_born_winner"].mean()

# Display the proportions of USA born winners per decade
prop_usa_winners
# Out:
#     decade  usa_born_winner
# 0     1900         0.017241
# 1     1910         0.075000
# 2     1920         0.074074
# 3     1930         0.241935
# 4     1940         0.288889
# 5     1950         0.278481
# 6     1960         0.262500
# 7     1970         0.308411
# 8     1980         0.313131
# 9     1990         0.392523
# 10    2000         0.414286
# 11    2010         0.336735

# %% [markdown]
# ## 4. USA dominance, visualized
# <p>A table is OK, but to <em>see</em> when the USA started to dominate the Nobel charts we need a plot!</p>

# %%
# Setting the plotting theme
sns.set()
# and setting the size of all plots.
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [11, 7]

# Plotting USA born winners 
ax = sns.lineplot(x="decade", y="usa_born_winner", data=prop_usa_winners)

# Adding %-formatting to the y-axis
from matplotlib.ticker import PercentFormatter
ax.yaxis.set_major_formatter(PercentFormatter(1.0))

# %% [markdown]
# ## 5. What is the gender of a typical Nobel Prize winner?
# <p>So the USA became the dominating winner of the Nobel Prize first in the 1930s and had kept the leading position ever since. But one group that was in the lead from the start, and never seems to let go, are <em>men</em>. Maybe it shouldn't come as a shock that there is some imbalance between how many male and female prize winners there are, but how significant is this imbalance? And is it better or worse within specific prize categories like physics, medicine, literature, etc.?</p>

# %%
# Calculating the proportion of female laureates per decade
nobel['female_winner'] = nobel["Sex"]=="Female"
prop_female_winners = nobel.groupby(["decade", "Category"], as_index=False)["female_winner"].mean()

sns.set()
# and setting the size of all plots.
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [11, 7]
 
ax = sns.lineplot(x="decade", y="female_winner", data=prop_female_winners, hue="Category")

# Adding %-formatting to the y-axis
from matplotlib.ticker import PercentFormatter
ax.yaxis.set_major_formatter(PercentFormatter(1.0))

# %% [markdown]
# ## 6. The first woman to win the Nobel Prize
# <p>The plot above is a bit messy as the lines are overplotting. But it does show some interesting trends and patterns. Overall the imbalance is pretty large with physics, economics, and chemistry having the largest imbalance. Medicine has a somewhat positive trend, and since the 1990s the literature prize is also now more balanced. The big outlier is the peace prize during the 2010s, but keep in mind that this just covers the years 2010 to 2016.</p>
# <p>Given this imbalance, who was the first woman to receive a Nobel Prize? And in what category?</p>

# %%
# Picking out the first woman to win a Nobel Prize
nobel[nobel["Sex"]=="Female"].nsmallest(n=1, columns="Year")
# Out:
#     Year Category                            Prize  \
# 19  1903  Physics  The Nobel Prize in Physics 1903
#
#                                            Motivation Prize Share  \
# 19  "in recognition of the extraordinary services ...         1/4
#
#     Laureate ID Laureate Type                    Full Name  Birth Date  \
# 19            6    Individual  Marie Curie, née Sklodowska  1867-11-07
#
#    Birth City  ...     Sex Organization Name Organization City  \
# 19     Warsaw  ...  Female               NaN               NaN
#
#    Organization Country  Death Date  Death City Death Country usa_born_winner  \
# 19                  NaN  1934-07-04  Sallanches        France           False
#
#     decade  female_winner
# 19    1900           True
#
# [1 rows x 21 columns]

# %% [markdown]
# ## 7. Repeat laureates
# <p>For most scientists/writers/activists a Nobel Prize would be the crowning achievement of a long career. But for some people, one is just not enough, and few have gotten it more than once. Who are these lucky few? (Having won no Nobel Prize myself, I'll assume it's just about luck.)</p>

# %%
# Selecting the laureates that have received 2 or more prizes.
nobel.groupby("Full Name").filter(lambda x: len(x)>=2)
# Out:
#      Year   Category                                           Prize  \
# 19   1903    Physics                 The Nobel Prize in Physics 1903
# 46   1908   Medicine  The Nobel Prize in Physiology or Medicine 1908
# 47   1908   Medicine  The Nobel Prize in Physiology or Medicine 1908
# 63   1911  Chemistry               The Nobel Prize in Chemistry 1911
# 90   1917      Peace                      The Nobel Peace Prize 1917
# ..    ...        ...                                             ...
# 942  2014    Physics                 The Nobel Prize in Physics 2014
# 945  2015  Chemistry               The Nobel Prize in Chemistry 2015
# 946  2015  Chemistry               The Nobel Prize in Chemistry 2015
# 947  2015  Chemistry               The Nobel Prize in Chemistry 2015
# 948  2015  Chemistry               The Nobel Prize in Chemistry 2015
#
#                                             Motivation Prize Share  \
# 19   "in recognition of the extraordinary services ...         1/4
# 46          "in recognition of their work on immunity"         1/2
# 47          "in recognition of their work on immunity"         1/2
# 63   "in recognition of her services to the advance...         1/1
# 90                                                 NaN         1/1
# ..                                                 ...         ...
# 942  "for the invention of efficient blue light-emi...         1/3
# 945            "for mechanistic studies of DNA repair"         1/3
# 946            "for mechanistic studies of DNA repair"         1/3
# 947            "for mechanistic studies of DNA repair"         1/3
# 948            "for mechanistic studies of DNA repair"         1/3
#
#      Laureate ID Laureate Type  \
# 19             6    Individual
# 46           302    Individual
# 47           302    Individual
# 63             6    Individual
# 90           482  Organization
# ..           ...           ...
# 942          906    Individual
# 945          921    Individual
# 946          921    Individual
# 947          922    Individual
# 948          922    Individual
#
#                                              Full Name  Birth Date  \
# 19                         Marie Curie, née Sklodowska  1867-11-07
# 46                                        Paul Ehrlich  1854-03-14
# 47                                        Paul Ehrlich  1854-03-14
# 63                         Marie Curie, née Sklodowska  1867-11-07
# 90   Comité international de la Croix Rouge (Intern...         NaN
# ..                                                 ...         ...
# 942                                      Isamu Akasaki  1929-01-30
# 945                                      Tomas Lindahl  1938-01-28
# 946                                      Tomas Lindahl  1938-01-28
# 947                                       Paul Modrich  1946-06-13
# 948                                       Paul Modrich  1946-06-13
#
#               Birth City  ...     Sex  \
# 19                Warsaw  ...  Female
# 46   Strehlen (Strzelin)  ...    Male
# 47   Strehlen (Strzelin)  ...    Male
# 63                Warsaw  ...  Female
# 90                   NaN  ...     NaN
# ..                   ...  ...     ...
# 942               Chiran  ...    Male
# 945            Stockholm  ...    Male
# 946            Stockholm  ...    Male
# 947            Raton, NM  ...    Male
# 948            Raton, NM  ...    Male
#
#                                      Organization Name      Organization City  \
# 19                                                 NaN                    NaN
# 46                               Goettingen University              Göttingen
# 47   Königliches Institut für experimentelle Therap...  Frankfurt-on-the-Main
# 63                                 Sorbonne University                  Paris
# 90                                                 NaN                    NaN
# ..                                                 ...                    ...
# 942                                  Nagoya University                 Nagoya
# 945                            Francis Crick Institute          Hertfordshire
# 946                              Clare Hall Laboratory          Hertfordshire
# 947                    Howard Hughes Medical Institute             Durham, NC
# 948                 Duke University School of Medicine             Durham, NC
#
#          Organization Country  Death Date                Death City  \
# 19                        NaN  1934-07-04                Sallanches
# 46                    Germany  1915-08-20  Bad Homburg vor der Höhe
# 47                    Germany  1915-08-20  Bad Homburg vor der Höhe
# 63                     France  1934-07-04                Sallanches
# 90                        NaN         NaN                       NaN
# ..                        ...         ...                       ...
# 942                     Japan         NaN                       NaN
# 945            United Kingdom         NaN                       NaN
# 946            United Kingdom         NaN                       NaN
# 947  United States of America         NaN                       NaN
# 948  United States of America         NaN                       NaN
#
#     Death Country usa_born_winner  decade  female_winner
# 19         France           False    1900           True
# 46        Germany           False    1900          False
# 47        Germany           False    1900          False
# 63         France           False    1910           True
# 90            NaN           False    1910          False
# ..            ...             ...     ...            ...
# 942           NaN           False    2010          False
# 945           NaN           False    2010          False
# 946           NaN           False    2010          False
# 947           NaN            True    2010          False
# 948           NaN            True    2010          False
#
# [128 rows x 21 columns]

# %% [markdown]
# ## 8. How old are you when you get the prize?
# <p>The list of repeat winners contains some illustrious names! We again meet Marie Curie, who got the prize in physics for discovering radiation and in chemistry for isolating radium and polonium. John Bardeen got it twice in physics for transistors and superconductivity, Frederick Sanger got it twice in chemistry, and Linus Carl Pauling got it first in chemistry and later in peace for his work in promoting nuclear disarmament. We also learn that organizations also get the prize as both the Red Cross and the UNHCR have gotten it twice.</p>
# <p>But how old are you generally when you get the prize?</p>

# %%
nobel.drop(nobel[ nobel['Birth Date'] == '1898-00-00'].index, inplace = True)
nobel.drop(nobel[ nobel['Birth Date'] == '1943-00-00'].index, inplace = True)
# 1898-00-00, 1943-00-00

# %%
# Converting birth_date from String to datetime
nobel['Birth Date'] = pd.to_datetime(nobel['Birth Date'])
# Calculating the age of Nobel Prize winners
nobel['age'] = nobel['Year']- nobel['Birth Date'].dt.year

# Plotting the age of Nobel Prize winners
sns.lmplot(x="Year", y="age", data=nobel, lowess=True, aspect=2,  line_kws={'color' : 'black'})
# lowess=True, aspect=2, and line_kws={'color' : 'black'}

# %% [markdown]
# ## 9. Age differences between prize categories
# <p>The plot above shows us a lot! We see that people use to be around 55 when they received the price, but nowadays the average is closer to 65. But there is a large spread in the laureates' ages, and while most are 50+, some are very young.</p>
# <p>We also see that the density of points is much high nowadays than in the early 1900s -- nowadays many more of the prizes are shared, and so there are many more winners. We also see that there was a disruption in awarded prizes around the Second World War (1939 - 1945). </p>
# <p>Let's look at age trends within different prize categories.</p>

# %%
# Same plot as above, but separate plots for each type of Nobel Prize
sns.lmplot(x='Year', y='age', row='Category', data=nobel, lowess=True, 
           aspect=2, line_kws={'color' : 'black'})

# %% [markdown]
# ## 10. Oldest and youngest winners
# <p>More plots with lots of exciting stuff going on! We see that both winners of the chemistry, medicine, and physics prize have gotten older over time. The trend is strongest for physics: the average age used to be below 50, and now it's almost 70. Literature and economics are more stable. We also see that economics is a newer category. But peace shows an opposite trend where winners are getting younger! </p>
# <p>In the peace category we also a winner around 2010 that seems exceptionally young. This begs the questions, who are the oldest and youngest people ever to have won a Nobel Prize?</p>

# %%
# The oldest winner of a Nobel Prize as of 2016
display(nobel.nlargest(5, 'age'))
# The youngest winner of a Nobel Prize as of 2016
display(nobel.nsmallest(5, 'age'))
# Out:
#      Year    Category                                              Prize  \
# 825  2007   Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 904  2012   Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 770  2002     Physics                    The Nobel Prize in Physics 2002
# 828  2007  Literature                 The Nobel Prize in Literature 2007
# 390  1966    Medicine     The Nobel Prize in Physiology or Medicine 1966
#
#                                             Motivation Prize Share  \
# 825  "for having laid the foundations of mechanism ...         1/3
# 904  "for the theory of stable allocations and the ...         1/2
# 770  "for pioneering contributions to astrophysics,...         1/4
# 828  "that epicist of the female experience, who wi...         1/1
# 390     "for his discovery of tumour-inducing viruses"         1/2
#
#      Laureate ID Laureate Type          Full Name Birth Date      Birth City  \
# 825          820    Individual     Leonid Hurwicz 1917-08-21          Moscow
# 904          883    Individual   Lloyd S. Shapley 1923-06-02   Cambridge, MA
# 770          753    Individual  Raymond Davis Jr. 1914-10-14  Washington, DC
# 828          817    Individual      Doris Lessing 1919-10-22      Kermanshah
# 390          383    Individual        Peyton Rous 1879-10-05   Baltimore, MD
#
#      ...           Organization Name Organization City  \
# 825  ...     University of Minnesota   Minneapolis, MN
# 904  ...    University of California   Los Angeles, CA
# 770  ...  University of Pennsylvania  Philadelphia, PA
# 828  ...                         NaN               NaN
# 390  ...      Rockefeller University      New York, NY
#
#          Organization Country  Death Date       Death City  \
# 825  United States of America  2008-06-24  Minneapolis, MN
# 904  United States of America  2016-03-12       Tucson, AZ
# 770  United States of America  2006-05-31   Blue Point, NY
# 828                       NaN  2013-11-17           London
# 390  United States of America  1972-02-16     New York, NY
#
#                 Death Country usa_born_winner decade  female_winner   age
# 825  United States of America           False   2000          False  90.0
# 904  United States of America            True   2010          False  89.0
# 770  United States of America            True   2000          False  88.0
# 828            United Kingdom           False   2000           True  88.0
# 390  United States of America            True   1960          False  87.0
#
# [5 rows x 22 columns]
#      Year Category                            Prize  \
# 940  2014    Peace       The Nobel Peace Prize 2014
# 86   1915  Physics  The Nobel Prize in Physics 1915
# 169  1932  Physics  The Nobel Prize in Physics 1932
# 174  1933  Physics  The Nobel Prize in Physics 1933
# 194  1936  Physics  The Nobel Prize in Physics 1936
#
#                                             Motivation Prize Share  \
# 940  "for their struggle against the suppression of...         1/2
# 86   "for their services in the analysis of crystal...         1/2
# 169  "for the creation of quantum mechanics, the ap...         1/1
# 174  "for the discovery of new productive forms of ...         1/2
# 194                "for his discovery of the positron"         1/2
#
#      Laureate ID Laureate Type                  Full Name Birth Date  \
# 940          914    Individual           Malala Yousafzai 1997-07-12
# 86            21    Individual     William Lawrence Bragg 1890-03-31
# 169           38    Individual     Werner Karl Heisenberg 1901-12-05
# 174           40    Individual  Paul Adrien Maurice Dirac 1902-08-08
# 194           43    Individual        Carl David Anderson 1905-09-03
#
#        Birth City  ...                             Organization Name  \
# 940       Mingora  ...                                           NaN
# 86       Adelaide  ...                           Victoria University
# 169      Würzburg  ...                            Leipzig University
# 174       Bristol  ...                       University of Cambridge
# 194  New York, NY  ...  California Institute of Technology (Caltech)
#
#     Organization City      Organization Country  Death Date       Death City  \
# 940               NaN                       NaN         NaN              NaN
# 86         Manchester            United Kingdom  1971-07-01          Ipswich
# 169           Leipzig                   Germany  1976-02-01           Munich
# 174         Cambridge            United Kingdom  1984-10-20  Tallahassee, FL
# 194      Pasadena, CA  United States of America  1991-01-11   San Marino, CA
#
#                 Death Country usa_born_winner decade  female_winner   age
# 940                       NaN           False   2010           True  17.0
# 86             United Kingdom           False   1910          False  25.0
# 169    West Germany (Germany)           False   1930          False  31.0
# 174  United States of America           False   1930          False  31.0
# 194  United States of America            True   1930          False  31.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 11. You get a prize!
# <p><img style="float: right;margin:20px 20px 20px 20px; max-width:200px" src="https://assets.datacamp.com/production/project_441/img/paint_nobel_prize.png"></p>
# <p>Hey! You get a prize for making it to the very end of this notebook! It might not be a Nobel Prize, but I made it myself in paint so it should count for something. But don't despair, Leonid Hurwicz was 90 years old when he got his prize, so it might not be too late for you. Who knows.</p>
# <p>Before you leave, what was again the name of the youngest winner ever who in 2014 got the prize for "[her] struggle against the suppression of children and young people and for the right of all children to education"?</p>

# %%
# The name of the youngest winner of the Nobel Prize as of 2016
youngest_winner = 'Malala Yousafzai'

# %% [markdown]
# ## 12. Prize Motivation
# <p>Nobel Laureates has given their motivation , finding the most frequent words used by them in their motivation texts. Word Cloud</p>

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: pillow in d:\anaconda\lib\site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: numpy>=1.6.1 in d:\anaconda\lib\site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Python program to generate WordCloud

# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

comment_words = ''
stopwords = set(STOPWORDS)
# print(stopwords)

# iterate through the csv file
for val in nobel.Motivation:
    # typecaste each val to string
    val = str(val)

    # split the value
    tokens = val.split()

    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()

    comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
wordcloud.words_.keys()
# Out:
# dict_keys(['discovery', 'development', 'discoveries concerning', 'work', 'theory', 'contribution', 'structure', 'method', 'recognition', 'nan', 'discoveries', 'economic', 'cell', 'analysis', 'new', 'chemical', 'studies', 'investigation', 'chemistry', 'invention', 'especially', 'mechanism', 'human', 'research', 'fundamental', 'synthesis', 'system', 'principle', 'concerning', 'effort', 'writing', 'important', 'field', 'physics', 'nan nan', 'poetry', 'electron', 'connection', 'life', 'effect', 'theoretical', 'form', 'poetic', 'pioneering', 'market', 'service', 'researches', 'production', 'use', 'novel', 'elementary particle', 'rendered', 'application', 'determination', 'great', 'nature', 'led', 'achievement', 'function', 'particle', 'particular', 'pioneering contributions', 'element', 'enzyme', 'biological', 'genetic', 'design', 'power', 'world', 'acid', 'molecular', 'conflict', 'processes', 'nuclear', 'compounds', 'epic', 'role', 'origin', 'problems', 'vitamin', 'regulation', 'understanding', 'interpretation', 'tradition', 'time', 'protein', 'molecule', 'international', 'fundamental work', 'organic synthesis', 'art', 'foundation', 'substances', 'equilibrium', 'high', 'quantum', 'man', 'interaction', 'semiconductor', 'extraordinary service', 'discoveries relating', 'x ray', 'pioneering work', 'artistic', 'history', 'radiation', 'people', 'knowledge', 'organic', 'called', 'observation', 'developed', 'reaction', 'made', 'properties', 'crystal', 'metabolism', 'hormone', 'organization', 'social', 'dynamic', 'discoveries regarding', 'chemical reactions', 'phenomena', 'outstanding', 'deep', 'energy', 'lyrical', 'experimental', 'imagination', 'means', 'rich', 'mass', 'demonstration', 'used', 'contemporary', 'nerve', 'existence', 'virus', 'prediction', 'culture', 'technique', 'structural', 'condition', 'empirical', 'neutrino', 'organ', 'democracy', 'atomic nuclei', 'narrative art', 'nucleic acid', 'mechanistic studies', 'opened', 'science', 'spirit', 'individual', 'drama', 'literature', 'matter', 'atomic', 'diffraction', 'inspired', 'growth', 'action', 'chromosome', 'catalytic', 'theories', 'decisive', 'universe', 'analyses', 'rna', 'change', 'peaceful', 'inter alia', 'high pressure', 'cell membrane', 'genetic control', 'three dimensional', 'dimensional structure', 'human rights', 'topological phase', 'sugar', 'disease', 'advancement', 'treatment', 'gases', 'style', 'force', 'optical', 'truth', 'penetrating', 'wide', 'immunity', 'study', 'literary', 'dramatic', 'helium', 'significance', 'law', 'spectroscopy'])

# %% [markdown]
# ### Most frequntly used words by Nobel Laureates:
# 1. discovery
# 2. developement
# 3. discoveries concerning
# 4. work
# 5. theory
# 6. contribution
# 7. structure
# 8. method
# 9. recognition
# 10. economic
